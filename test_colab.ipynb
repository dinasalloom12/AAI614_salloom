# %% [markdown]
# <a href="https://colab.research.google.com/github/dinasalloom12/AAI614_salloom/blob/main/test_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Link to my repo:  https://github.com/dinasalloom12/AAI614_salloom

# %%
print("Hello")
print("This is my Colab notebook for AAI614!")
# Out:
# Hello
# This is my Colab notebook for AAI614!
